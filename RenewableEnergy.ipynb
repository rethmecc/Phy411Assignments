# %%
import numpy.random as random
import numpy as np
import matplotlib.mlab as mlab
import scipy.stats as stats
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from scipy.integrate import simps, trapz
import pylab as plb
from scipy.optimize import curve_fit
from scipy import asarray as ar,exp

# %%
Full=np.genfromtxt('RE/Full.txt')
DarkBlue=np.genfromtxt('RE/DarkBlue.txt')
DarkMagenta=np.genfromtxt('RE/DarkMagenta.txt')
DarkOrange=np.genfromtxt('RE/DarkOrange.txt')
DarkPink=np.genfromtxt('RE/DarkPink.txt')
DarkPurple=np.genfromtxt('RE/DarkPurple.txt')
DarkYellow=np.genfromtxt('RE/DarkYellow.txt')
Green=np.genfromtxt('RE/Green.txt')
LightBlue=np.genfromtxt('RE/LightBlue.txt')
LightMagenta=np.genfromtxt('RE/LightMagenta.txt')
LightOrange=np.genfromtxt('RE/LightOrange.txt')
LightPink=np.genfromtxt('RE/LightPink.txt')
LightPurple=np.genfromtxt('RE/LightPurple.txt')
LightYellow=np.genfromtxt('RE/LightYellow.txt')
White=np.genfromtxt('RE/White.txt')
Full2=np.genfromtxt('RE/Full2.txt')
DBlueDOrange=np.genfromtxt('RE/DBlueDOrange.txt')
LPurpleDMagenta=np.genfromtxt('RE/LPurpleDMagenta.txt')

fig,ax=plt.subplots(6,3)
fig.set_size_inches(20,15)
ax[0][0].plot(Full[:,0],Full[:,1],label='Full')
ax[0][1].plot(DarkBlue[:,0],DarkBlue[:,1],label='DarkBlue')
ax[0][2].plot(DarkMagenta[:,0],DarkMagenta[:,1],label='DarkMagenta')
ax[1][0].plot(DarkOrange[:,0],DarkOrange[:,1],label='DarkOrange')
ax[1][1].plot(DarkPink[:,0],DarkPink[:,1],label='DarkPink')
ax[1][2].plot(DarkPurple[:,0],DarkPurple[:,1],label='DarkPurple')
ax[2][0].plot(DarkYellow[:,0],DarkYellow[:,1],label='DarkYellow')
ax[2][1].plot(Green[:,0],Green[:,1],label='Green')
ax[2][2].plot(LightBlue[:,0],LightBlue[:,1],label='LightBlue')
ax[3][0].plot(LightMagenta[:,0],LightMagenta[:,1],label='LightMagenta')
ax[3][1].plot(LightOrange[:,0],LightOrange[:,1],label='LightOrange')
ax[3][2].plot(LightPink[:,0],LightPink[:,1],label='LightPink')
ax[4][0].plot(LightPurple[:,0],LightPurple[:,1],label='LightPurple')
ax[4][1].plot(LightYellow[:,0],LightYellow[:,1],label='LightYellow')
ax[4][2].plot(White[:,0],White[:,1],label='White')
ax[5][0].plot(Full2[:,0],Full2[:,1],label='Full2')
ax[5][1].plot(DBlueDOrange[:,0],DBlueDOrange[:,1],label='DBlueDOrange')
ax[5][2].plot(LPurpleDMagenta[:,0],LPurpleDMagenta[:,1],label='LPurpleDMagenta')
for i in range(6):
    for j in range(3):
        ax[i][j].legend()

# %%
Comb1=DarkPink-LightBlue*0.8+DarkOrange*0.5-DarkPurple+White*0.8-DarkMagenta*0.4
Comb2=Green
fig,ax=plt.subplots(2,2)
fig.set_size_inches(20,10)
#ax[0][0].plot(DarkMagenta[:,0],DarkMagenta[:,1],label='DarkMagenta',color=((1,0,1)))
#ax[0][0].plot(LightPurple[:,0],LightPurple[:,1],label='LightPurple',color=((64/255.,0,0.5)))
ax[0][0].plot(LightBlue[:,0],LightBlue[:,1]*0.75,label='LightBlue',color=((0,0,0.5)))
ax[0][0].plot(LPurpleDMagenta[:,0],LPurpleDMagenta[:,1]*0.75,label='LPurDMag',color='c')
ax[0][0].plot(LPurpleDMagenta[:,0],DBlueDOrange[:,1],label='DBlueDOrange',color='y')
ax[0][0].plot(DarkPurple[:,0],DarkPurple[:,1]*0.6,label='DarkPurple',color=(128/255.,0,1))
COMB1=LightBlue[:,1]*0.75-DarkPurple[:,1]*0.6
ax[0][0].plot(DarkOrange[:,0],DarkMagenta[:,1]-LightPurple[:,1]+LightBlue[:,1]*0.75-LPurpleDMagenta[:,1]*0.7,color='r')
ax[0][0].plot(DarkOrange[:,0],COMB1,color='k',label='COMB1')
ax[0][1].plot(Full[:,0],LightBlue[:,1]*0.8,label='LightBlue*0.8')
ax[0][1].plot(Full[:,0],DarkOrange[:,1]*0.5,label='DarkOrange*0.5')
ax[1][0].plot(Full[:,0],Full[:,1],label='Full')
fig2,bx=plt.subplots(1,1)
fig2.set_size_inches(40,20)
bx.plot(DarkBlue[:,0],DarkBlue[:,1],label='DarkBlue',color=((0,0,1)))
bx.plot(DarkMagenta[:,0],DarkMagenta[:,1],label='DarkMagenta',color=((1,0,1)))
bx.plot(DarkOrange[:,0],DarkOrange[:,1],label='DarkOrange',color=((1,0.5,0)))
bx.plot(DarkPink[:,0],DarkPink[:,1],label='DarkPink',color=((1,192/255.,203/255.)))
bx.plot(DarkPurple[:,0],DarkPurple[:,1],label='DarkPurple',color=(128/255.,0,1))
bx.plot(DarkYellow[:,0],DarkYellow[:,1],label='DarkYellow',color=((1,1,0)))
bx.plot(Green[:,0],Green[:,1],label='Green',color='g')
bx.plot(LightBlue[:,0],LightBlue[:,1],label='LightBlue',color=((0,0,0.5)))
bx.plot(LightMagenta[:,0],LightMagenta[:,1],label='LightMagenta',color=((0.5,0,0.5)))
bx.plot(LightOrange[:,0],LightOrange[:,1],label='LightOrange',color=((0.5,0.25,0)))
bx.plot(LightPink[:,0],LightPink[:,1],label='LightPink',color=((0.5,162/255./2.,203/255./2.)))
bx.plot(LightPurple[:,0],LightPurple[:,1],label='LightPurple',color=((64/255.,0,0.5)))
bx.plot(LightYellow[:,0],LightYellow[:,1],label='LightYelow',color=((0.5,0.5,0)))
#bx.plot(White[:,0],White[:,1],label='White',color='k')
bx.legend()
ax[1][0].legend()
ax[0][0].legend()
ax[0][1].legend()

# %%
fig,ax=plt.subplots(1,1)
fig.set_size_inches(15,9)

peak1=DarkOrange[:,1]-DarkMagenta[:,1]
peak2=DarkYellow[:,1]-DarkOrange[:,1]
peak3=DarkPurple[:,1]-DarkBlue[:,1]
peak4=DBlueDOrange[:,1]

ax.plot(DarkOrange[:,0],peak1,label='peak1')
ax.plot(DarkOrange[:,0],peak2,label='peak2')
ax.plot(DarkOrange[:,0],peak3,label='peak3')
ax.plot(DBlueDOrange[:,0],peak4,label='peak4')
ax.legend()

# %%
wl435nm=np.genfromtxt('Project/435nm.txt')
wl500nm=np.genfromtxt('Project/500nm.txt')
wl633nm=np.genfromtxt('Project/633nm.txt')
Blue=np.genfromtxt('Project/Blue.txt')
Cyan=np.genfromtxt('Project/Cyan.txt')
Green=np.genfromtxt('Project/Green.txt')
Magenta=np.genfromtxt('Project/Magenta.txt')
Red=np.genfromtxt('Project/Red.txt')
White=np.genfromtxt('Project/White.txt')
Yellow=np.genfromtxt('Project/Yellow.txt')

fig,ax=plt.subplots(5,2)
fig.set_size_inches(18.5,14)
ax[0][0].plot(wl435nm[:,0],wl435nm[:,1],label='435nm')
ax[0][1].plot(wl500nm[:,0],wl500nm[:,1],label='500nm')
ax[1][0].plot(wl633nm[:,0],wl633nm[:,1],label='633nm')
ax[1][1].plot(Blue[:,0],Blue[:,1],label='Blue')
ax[2][0].plot(Cyan[:,0],Cyan[:,1],label='Cyan')
ax[2][1].plot(Green[:,0],Green[:,1],label='Green')
ax[3][0].plot(Magenta[:,0],Magenta[:,1],label='Magenta')
ax[3][1].plot(Red[:,0],Red[:,1],label='Red')
ax[4][0].plot(White[:,0],White[:,1],label='White')
ax[4][1].plot(Yellow[:,0],Yellow[:,1],label='Yellow')
for i in range(5):
    for j in range(2):
        ax[i][j].legend()

# %%
fig,ax=plt.subplots(1,1)
fig.set_size_inches(15,8)

Peak1=Blue[:,1]-wl435nm[:,1]*0-wl500nm[:,1]*0.0
ax.plot(Blue[:,0],Blue[:,1],label='Blue',color='b')
#ax.plot(Blue[:,0],Blue[:,1]*3+Red[:,1]*2.4+Green[:,1]*1.3,label='All',color='c')
#ax.plot(Yellow[:,0],Yellow[:,1]-wl633nm[:,1],label='Yelow-633nm',color='r')
ax.plot(Green[:,0],Green[:,1]*2.4,label='Green',color='g')
ax.plot(Red[:,0],Red[:,1]*2.4,label='Red',color='r')
ax.plot(wl500nm[:,0],wl500nm[:,1]-Green[:,1]*0.975-Blue[:,1]*0.5,label='500nm',color=((0,1,127/255.)))
#cmb1=White[:,1]-(wl500nm[:,1]*2.43+Red[:,1]*2.4)-Blue[:,1]*0.5
#ax.plot(White[:,0],cmb1,label='White Comb',color='m')
#cmb2=White[:,1]-(wl500nm[:,1]*2.1-Blue[:,1]+wl633nm[:,1]*4-Red[:,1]*1.2)
#ax.plot(White[:,0],cmb2,label='White Comb2',color='b')
#ax.plot(White[:,0],cmb1-cmb2,label='Comb1-Comb2',color='r')
ax.plot(White[:,0],White[:,1],label='White',color='k')
#ax.plot(White[:,0],wl500nm[:,1]-Blue[:,1]*0.5,label='Second peak',color='b')
#ax.plot(wl633nm[:,0],(wl633nm[:,1]-Red[:,1]*0.95),label='633nm',color=((1,47/255.,0)))
#ax.plot(wl633nm[:,0],wl500nm[:,1]-Blue[:,1]*0.5-Green[:,1],label='peak1.2',color='m')
ax.plot(wl633nm[:,0],White[:,1]-(Green[:,1]*2.4),label='peak1.2',color='m')
ax.plot(wl633nm[:,0],White[:,1]-Blue[:,1]*2.8-Red[:,1]*2.4,label='peak4',color='c')
ax.legend()
#ax.plot(White[:,0],Peak1)

# %%
fig,ax=plt.subplots(1,1)
fig.set_size_inches(15,9)

cmb1=White[:,1]-(Green[:,1]*2.4+Blue[:,1]*0.1+Red[:,1]*2.4)
cmb2=White[:,1]-Blue[:,1]*2.8-Red[:,1]*2.4
cmb3=Red[:,1]

ax.plot(White[:,0],cmb1,label='cmb1')
ax.plot(White[:,0],cmb2,label='cmb2')
ax.plot(White[:,0],cmb3,label='cmb3')

# %%
fig,ax=plt.subplots(2,1)
fig.set_size_inches(15,18)

ax[0].plot(Full[:,0],peak1*1240./Full[:,0],label='peak1')
ax[0].plot(Full[:,0],peak2*1240./Full[:,0],label='peak2')
ax[0].plot(Full[:,0],peak3*1240./Full[:,0],label='peak3')
ax[0].plot(Full[:,0],peak4*1240./Full[:,0],label='peak4')
ax[0].plot(Full[:,0],cmb1*1240./Full[:,0],label='cmb1')
ax[0].plot(Full[:,0],cmb2*1240./Full[:,0],label='cmb2')
ax[0].plot(Full[:,0],cmb3*1240./Full[:,0],label='cmb3')
ax[0].legend()

print 1240./Full[:,0]
Is=simps(peak1*1240./Full[:,0],x=Full[:,0])
It=simps(Full[:,1]*1240./Full[:,0],x=Full[:,0])
print Is/It
ax[1].fill(Full[:,0],Full[:,1]*1240./Full[:,0],label='Full spectrum',color='k',alpha=0.25)
ax[1].fill(Full[:,0],peak1*1240./Full[:,0],label='Peak1',color='b',alpha=0.5)
ax[1].plot(DarkMagenta[:,0],DarkMagenta[:,1]*1240./Full[:,0],label='Dark Magenta',color=((1,0,1)))
ax[1].plot(DarkOrange[:,0],DarkOrange[:,1]*1240./Full[:,0],label='Dark Orange',color=((1,0.5,0)))
ax[1].grid()
ax[1].legend()
# Out:
# [ 3.64320132  3.63924515  3.63519099 ...,  1.21974012  1.21940426
#   1.21906859]
# 0.208110592131

# %%
fig,ax=plt.subplots(2,1)
fig.set_size_inches(15,18)

ax[0].plot(Full[:,0],peak1,label='peak1')
ax[0].plot(Full[:,0],peak2,label='peak2')
ax[0].plot(Full[:,0],peak3,label='peak3')
ax[0].plot(Full[:,0],peak4,label='peak4')
ax[0].plot(Full[:,0],cmb1,label='cmb1')
ax[0].plot(Full[:,0],cmb2,label='cmb2')
ax[0].plot(Full[:,0],cmb3,label='cmb3')

ax[1].plot(Full[:,0],peak1*1240./Full[:,0],label='peak1')
ax[1].plot(Full[:,0],peak2*1240./Full[:,0],label='peak2')
ax[1].plot(Full[:,0],peak3*1240./Full[:,0],label='peak3')
ax[1].plot(Full[:,0],peak4*1240./Full[:,0],label='peak4')
ax[1].plot(Full[:,0],cmb1*1240./Full[:,0],label='cmb1')
ax[1].plot(Full[:,0],cmb2*1240./Full[:,0],label='cmb2')
ax[1].plot(Full[:,0],cmb3*1240./Full[:,0],label='cmb3')
ax[0].legend()
ax[1].legend()

# %%
fig,ax=plt.subplots(4,2)
fig.set_size_inches(15,18)

def gaus(x,a,x0,sigma):
    return a*exp(-(x-x0)**2/(2*sigma**2))

It=simps(Full[:,1]*1240./Full[:,0],x=Full[:,0])

Is=simps(peak1*1240./Full[:,0],x=Full[:,0])
print Is/It
ax[0][0].fill(Full[:,0],Full[:,1]*1240./Full[:,0],label='Full spectrum',color='k',alpha=0.25)
ax[0][0].fill(Full[:,0],peak1*1240./Full[:,0],label='Peak1',color=(1,247/255.,0),alpha=0.5)
ax[0][0].plot(DarkMagenta[:,0],DarkMagenta[:,1]*1240./Full[:,0],label='Dark Magenta',color=((1,0,1)))
ax[0][0].plot(DarkOrange[:,0],DarkOrange[:,1]*1240./Full[:,0],label='Dark Orange',color=((1,0.5,0)))
ax[0][0].grid()
loc=np.where(peak1==max(peak1))[0]
mean=Full[loc,0]
sigma = np.std(peak1*1240./Full[:,0])
popt,pcov = curve_fit(gaus,Full[:,0],peak1*1240./Full[:,0],p0=[5500,mean,sigma])
print popt
ax[0][0].plot(Full[:,0],gaus(Full[:,0],*popt),'ro:',label='fit')
ax[0][0].legend()
ax[0][0].set_ylabel('Energy (arbitrary units)')
ax[0][0].set_xlabel('Wavelength (nm)')

Is=simps(peak2*1240./Full[:,0],x=Full[:,0])
print Is/It
ax[0][1].fill(Full[:,0],Full[:,1]*1240./Full[:,0],label='Full spectrum',color='k',alpha=0.25)
ax[0][1].fill(Full[:,0],peak2*1240./Full[:,0],label='Peak2',color=(105/255.,1,0),alpha=0.5)
ax[0][1].plot(DarkMagenta[:,0],DarkYellow[:,1]*1240./Full[:,0],label='Dark Yellow',color=((1,1,0)))
ax[0][1].plot(DarkOrange[:,0],DarkOrange[:,1]*1240./Full[:,0],label='Dark Orange',color=((1,0.5,0)))
ax[0][1].grid()
loc=np.where(peak2==max(peak2))[0]
mean=Full[loc,0]
sigma = np.std(peak2*1240./Full[:,0])
popt,pcov = curve_fit(gaus,Full[:,0],peak2*1240./Full[:,0],p0=[5500,mean,sigma])
print popt
ax[0][1].plot(Full[:,0],gaus(Full[:,0],*popt),'ro:',label='fit')
ax[0][1].legend()
ax[0][1].set_ylabel('Energy (arbitrary units)')
ax[0][1].set_xlabel('Wavelength (nm)')

Is=simps(peak3*1240./Full[:,0],x=Full[:,0])
print Is/It
ax[1][0].fill(Full[:,0],Full[:,1]*1240./Full[:,0],label='Full spectrum',color='k',alpha=0.25)
ax[1][0].fill(Full[:,0],peak3*1240./Full[:,0],label='Peak3',color=(234/255.,0,0),alpha=0.5)
ax[1][0].plot(DarkPurple[:,0],DarkPurple[:,1]*1240./Full[:,0],label='Dark Purple',color=(128/255.,0,1))
ax[1][0].plot(DarkBlue[:,0],DarkBlue[:,1]*1240./Full[:,0],label='Dark Blue',color=((0,0,1)))
ax[1][0].grid()
loc=np.where(peak3==max(peak3))[0]
mean=Full[loc,0]
sigma = np.std(peak3*1240./Full[:,0])
popt,pcov = curve_fit(gaus,Full[:,0],peak3*1240./Full[:,0],p0=[5500,mean,sigma])
print popt
ax[1][0].plot(Full[:,0],gaus(Full[:,0],*popt),'ro:',label='fit')
ax[1][0].legend()
ax[1][0].set_ylabel('Energy (arbitrary units)')
ax[1][0].set_xlabel('Wavelength (nm)')

Is=simps(peak4*1240./Full2[:,0],x=Full2[:,0])
print Is/It
ax[1][1].fill(Full2[:,0],Full2[:,1]*1240./Full2[:,0],label='Full spectrum',color='k',alpha=0.25)
ax[1][1].fill(Full2[:,0],peak4*1240./Full[:,0],label='Peak4',color=(0,0,0),alpha=0.5)
ax[1][1].plot(DBlueDOrange[:,0],DBlueDOrange[:,1]*1240./Full[:,0],label='Dark Blue & Dark Orange',color='y')
ax[1][1].grid()
loc=np.where(peak4==max(peak4))[0]
mean=Full[loc,0]
sigma = np.std(peak4*1240./Full[:,0])
popt,pcov = curve_fit(gaus,Full[:,0],peak4*1240./Full[:,0],p0=[5500,mean,sigma])
print popt
ax[1][1].plot(Full[:,0],gaus(Full[:,0],*popt),'ro:',label='fit')
ax[1][1].legend()
ax[1][1].set_ylabel('Energy (arbitrary units)')
ax[1][1].set_xlabel('Wavelength (nm)')

Is=simps(cmb1*1240./White[:,0],x=White[:,0])
print Is/It
ax[2][0].fill(White[:,0],White[:,1]*1240./White[:,0],label='Full spectrum',color='k',alpha=0.25)
ax[2][0].fill(White[:,0],cmb1*1240./White[:,0],label='Cmb1',color=(0,45./255,1),alpha=0.5)
ax[2][0].plot(White[:,0],White[:,1]*1240./White[:,0],label='White',color='k')
ax[2][0].plot(Green[:,0],Green[:,1]*1240./White[:,0]*2.4,label='Green',color=(0,1,0))
ax[2][0].plot(Blue[:,0],Blue[:,1]*1240./White[:,0]*0.1,label='Blue',color=((0,0,1)))
ax[2][0].plot(Red[:,0],Red[:,1]*1240./White[:,0]*2.4,label='Red',color=((1,0,0)))
ax[2][0].grid()
loc=np.where(cmb1==max(cmb1))[0]
mean=Full[loc,0]
sigma = np.std(cmb1*1240./Full[:,0])
popt,pcov = curve_fit(gaus,Full[:,0],cmb1*1240./Full[:,0],p0=[5500,mean,sigma])
print popt
ax[2][0].plot(Full[:,0],gaus(Full[:,0],*popt),'ro:',label='fit')
ax[2][0].legend()
ax[2][0].set_ylabel('Energy (arbitrary units)')
ax[2][0].set_xlabel('Wavelength (nm)')

Is=simps(cmb2*1240./White[:,0],x=White[:,0])
print Is/It
ax[2][1].fill(White[:,0],White[:,1]*1240./White[:,0],label='Full spectrum',color='k',alpha=0.25)
ax[2][1].fill(White[:,0],cmb2*1240./White[:,0],label='Cmb2',color=(149./255,1,0),alpha=0.5)
ax[2][1].plot(White[:,0],White[:,1]*1240./White[:,0],label='White',color='k')
ax[2][1].plot(Blue[:,0],Blue[:,1]*1240./White[:,0]*2.8,label='Blue',color=((0,0,1)))
ax[2][1].plot(Red[:,0],Red[:,1]*1240./White[:,0]*2.4,label='Red',color=((1,0,0)))
ax[2][1].grid()
loc=np.where(cmb2==max(cmb2))[0]
mean=Full[loc,0]
sigma = np.std(cmb2*1240./Full[:,0])
popt,pcov = curve_fit(gaus,Full[:,0],cmb2*1240./Full[:,0],p0=[5500,mean,sigma])
print popt
ax[2][1].plot(Full[:,0],gaus(Full[:,0],*popt),'ro:',label='fit')
ax[2][1].legend()
ax[2][1].set_ylabel('Energy (arbitrary units)')
ax[2][1].set_xlabel('Wavelength (nm)')

Is=simps(cmb1*1240./White[:,0],x=White[:,0])
print Is/It
ax[3][0].fill(White[:,0],White[:,1]*1240./White[:,0],label='Full spectrum',color='k',alpha=0.25)
ax[3][0].fill(White[:,0],cmb3*1240./White[:,0],label='Cmb3',color=(1,156/255.,0),alpha=0.5)
ax[3][0].plot(Red[:,0],Red[:,1]*1240./White[:,0],label='Red',color=((1,0,0)))
ax[3][0].grid()
loc=np.where(cmb3==max(cmb3))[0][0]
mean=Full[loc,0]
sigma = np.std(cmb3*1240./Full[:,0])
popt,pcov = curve_fit(gaus,Full[:,0],cmb3*1240./Full[:,0],p0=[5500,mean,sigma])
print popt
ax[3][0].plot(Full[:,0],gaus(Full[:,0],*popt),'ro:',label='fit')
ax[3][0].legend()
ax[3][0].set_ylabel('Energy (arbitrary units)')
ax[3][0].set_xlabel('Wavelength (nm)')
ax[3][1].set_visible(False)
# Out:
# 0.208110592131
# [ 5148.71996767   581.9126008     29.46078419]
# 0.0873957190532
# [ 3390.00611734   538.62297751    25.86239226]
# 0.142031882428
# [ 3263.40506626   709.31439348   -35.25989541]
# 0.0538121748395
# [ 586.74229848  786.38413867   49.54864684]
# 0.134424430655
# [ 3899.38362995   448.75728931    23.28288187]
# 0.159077351392
# [ 4713.12377896   550.83069608    22.378006  ]
# 0.134424430655
# [ 629.37678279  604.50449709   25.03533387]

# %%
def gaus(x,a,x0,sigma):
    return a*exp(-(x-x0)**2/(2*sigma**2))
n = len(Full[:,0])
loc=np.where(peak1==max(peak1))[0]
mean=Full[loc,0]
print mean
sigma = np.std(peak1*1240./Full[:,0])
popt,pcov = curve_fit(gaus,Full[:,0],peak1*1240./Full[:,0],p0=[5500,mean,sigma])

print popt

fig,ax=plt.subplots(1,1)
ax.plot(Full[:,0],peak1*1240./Full[:,0],'b+:',label='data')
ax.plot(Full[:,0],gaus(Full[:,0],*popt),'ro:',label='fit')
ax.legend()
# Out:
# [ 593.71]
# [ 5148.71996767   581.9126008     29.46078419]

# %%
scale=np.array([0.208110592131,0.0873957190532,0.142031882428,0.0538121748395,0.134424430655,0.159077351392,0.134424430655])
power=np.array([120.615-54.18,154.76-120.615,18.40-4.42,0.827,
                41.08/6.22-1.567*2.4-0.775*0.1-2.4*0.406,41.08/6.22-2.8*0.775-2.4*0.406,0.406])
fullP=np.array([275.155,275.155,275.155,288.672,41.08,41.08,41.08])
fullPerr=np.array([0.7,0.7,0.7,0.8,0.3,0.3,0.3])

value=power/fullP/scale
error0=np.array([0.5**2+0.3**2,0.6**2+0.5**2,0.2**2+0.09**2,0.04**2,
                0.3**2+(0.06*2.4)**2+(0.04*0.1)**2+(2.4*0.03)**2,0.3**2+(2.8*0.04)**2+(2.4*0.03)**2,0.03**2])
error=np.sqrt(error0/power**2+(fullPerr/fullP)**2)*value

sigma=np.array([29.46078419,25.86239226,35.25989541,49.54864684,23.28288187,22.378006,25.03533387])
mean=np.array([581.9126008,538.62297751,709.31439348,786.38413867,448.75728931,550.83069608,604.50449709])

print scale
print power
print error0
print fullP
print fullPerr
print value
print error
# Out:
# [ 0.20811059  0.08739572  0.14203188  0.05381217  0.13442443  0.15907735
#   0.13442443]
# [ 66.435       34.145       13.98         0.827        1.79180161
#    3.46010161   0.406     ]
# [ 0.34      0.61      0.0481    0.0016    0.115936  0.107728  0.0009  ]
# [ 275.155  275.155  275.155  288.672   41.08    41.08    41.08 ]
# [ 0.7  0.7  0.7  0.8  0.3  0.3  0.3]
# [ 1.16017992  1.41990585  0.35772057  0.05323782  0.32447503  0.52948062
#   0.07352201]
# [ 0.01060194  0.03267886  0.0056852   0.00257921  0.06170509  0.05037427
#   0.00545913]

# %%
fig,ax=plt.subplots(2,1)
fig.set_size_inches(7.5,9)
ax[0].set_xlim(400,850)
ax[1].set_xlim(400,850)
ax[0].errorbar(mean[:4],value[:4],xerr=sigma[:4],yerr=error[:4],fmt='.',label='Halogen')
ax[1].errorbar(mean[4:],value[4:],xerr=sigma[4:],yerr=error[4:],fmt='.',label='Projector')
ax[1].set_xlabel('Wavelength (nm)')
ax[0].set_ylabel('Energy (arbitraty units)')
ax[1].set_ylabel('Energy (arbitraty units)')
ax[0].legend()
ax[1].legend()

# %%
fig,ax=plt.subplots(1,1)
fig.set_size_inches(7.5,4.5)

#ax.plot(Blue[:,0],Blue[:,1],label='Blue',color='b')
#ax.plot(Green[:,0],Green[:,1],label='Green',color='g')
#ax.plot(Red[:,0],Red[:,1],label='Red',color='r')
ax.plot(White[:,0],White[:,1],label='White',color='k')
ax.plot(White[:,0],Blue[:,1]*2.4+Green[:,1]*2.4+Red[:,1]*2.4,label='Constructed',color='m')
comp=Blue[:,1]+Green[:,1]+Red[:,1]
ax.legend()
ax.grid(True)
ax.set_ylabel('Energy (arbitrary units)')
ax.set_xlabel('Wavelength (nm)')

# %%
It=simps(comp*1240./Full[:,0],x=Full[:,0])
Ib=simps(Blue[:,1]*1240./Full[:,0],x=Full[:,0])
Ir=simps(Red[:,1]*1240./Full[:,0],x=Full[:,0])
Ig=simps(Green[:,1]*1240./Full[:,0],x=Full[:,0])
projScale=np.array([Ib,Ig,Ir])/It
power=np.array([0.775,1.567,0.406])
value=power/projScale
fig,ax=plt.subplots(1,1)
ax.plot((450,550,600),value,'.')
